# %%
# Pip install (recommended)

# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.72  Python-3.8.20 torch-2.4.1+cpu CPU (Intel Core(TM) i5-6300U 2.40GHz)
# Setup complete  (4 CPUs, 7.4 GB RAM, 29.0/127.0 GB disk)

# %% [markdown]
# Training

# %%
# !yolo task=detect mode=train model="yolov8s.pt" data="E:\07-12_yolo\yolov8\dataset.yaml" epochs=100 imgsz=640 batch=8 project="E:\07-12_yolo\yolov8\training_results" name=sku

# %% [markdown]
# pytorch Inference

# %%
# !yolo task=detect mode=predict model="E:\07-12_yolo\yolov8\training_results\sku\weights\best.pt" conf=0.55 source="E:\07-12_yolo\dataset\images\test_images"
# Out:
# Ultralytics 8.3.72 🚀 Python-3.8.20 torch-2.4.1+cpu CPU (Intel Core(TM) i5-6300U 2.40GHz)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/100 E:\07-12_yolo\dataset\images\test_images\0154f412-8e20-4c65-9924-de631bd06be4_1_1_1_2_2024-11-30T07-00-49_8904272600154_51.png: 384x640 1 sku, 461.8ms
# image 2/100 E:\07-12_yolo\dataset\images\test_images\0404e639-57ed-403d-8fc3-eb97c9249534_3_7_2_9_2024-12-02T13-38-54_8901262010023_90.png: 384x640 2 skus, 386.0ms
# image 3/100 E:\07-12_yolo\dataset\images\test_images\0439ff72-1bb5-4339-9cb7-ecd1cbbb9d84_3_2_1_3_2024-11-30T04-46-49_unknown_18.png: 384x640 3 skus, 376.0ms
# image 4/100 E:\07-12_yolo\dataset\images\test_images\0759be7a-11d3-42b9-a990-0601baedb53c_3_3_1_4_2024-11-19T17-03-56_12.png: 384x640 2 skus, 310.3ms
# image 5/100 E:\07-12_yolo\dataset\images\test_images\0759be7a-11d3-42b9-a990-0601baedb53c_3_5_1_6_2024-11-19T17-04-18_154.png: 384x640 6 skus, 545.6ms
# ...

# %% [markdown]
# inferencing on video

# %%
# !yolo task=detect mode=predict model="best.pt" conf=0.77 source=""

# %% [markdown]
# ONNX Inference

# %%
# !yolo task=detect mode=predict model="E:\07-12_yolo\yolov8\training_results\sku\weights\best.onnx" conf=0.55 source="E:\07-12_yolo\dataset\images\test_images"
# Out:
# Ultralytics 8.3.72 🚀 Python-3.8.20 torch-2.4.1+cpu CPU (Intel Core(TM) i5-6300U 2.40GHz)
# Loading E:\07-12_yolo\yolov8\training_results\sku\weights\best.onnx for ONNX Runtime inference...
# Using ONNX Runtime CPUExecutionProvider
#
# image 1/100 E:\07-12_yolo\dataset\images\test_images\0154f412-8e20-4c65-9924-de631bd06be4_1_1_1_2_2024-11-30T07-00-49_8904272600154_51.png: 384x640 1 sku, 299.2ms
# image 2/100 E:\07-12_yolo\dataset\images\test_images\0404e639-57ed-403d-8fc3-eb97c9249534_3_7_2_9_2024-12-02T13-38-54_8901262010023_90.png: 384x640 2 skus, 406.9ms
# image 3/100 E:\07-12_yolo\dataset\images\test_images\0439ff72-1bb5-4339-9cb7-ecd1cbbb9d84_3_2_1_3_2024-11-30T04-46-49_unknown_18.png: 384x640 3 skus, 346.1ms
# image 4/100 E:\07-12_yolo\dataset\images\test_images\0759be7a-11d3-42b9-a990-0601baedb53c_3_3_1_4_2024-11-19T17-03-56_12.png: 384x640 2 skus, 307.9ms
# ...
